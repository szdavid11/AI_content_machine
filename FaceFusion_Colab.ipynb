# %% [markdown]
# <a href="https://colab.research.google.com/github/szdavid11/AI_content_machine/blob/main/FaceFusion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu
# Out:
# Cloning into 'facefusion'...
# remote: Enumerating objects: 4387, done.
# remote: Counting objects: 100% (573/573), done.
# remote: Compressing objects: 100% (323/323), done.
# remote: Total 4387 (delta 406), reused 264 (delta 250), pack-reused 3814 (from 4)
# Receiving objects: 100% (4387/4387), 25.90 MiB | 28.13 MiB/s, done.
# Resolving deltas: 100% (2839/2839), done.
# /content/facefusion
# Collecting gradio-rangeslider==0.0.8 (from -r requirements.txt (line 1))
#   Downloading gradio_rangeslider-0.0.8-py3-none-any.whl.metadata (10 kB)
# Collecting gradio==5.44.1 (from -r requirements.txt (line 2))
#   Downloading gradio-5.44.1-py3-none-any.whl.metadata (16 kB)
# Collecting numpy==2.3.4 (from -r requirements.txt (line 3))
#   Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.9 MB/s eta 0:00:00
# Collecting onnx==1.19.1 (from -r requirements.txt (line 4))
#   Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Collecting onnxruntime==1.23.2 (from -r requirements.txt (line 5))
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: opencv-python==4.12.0.88 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (4.12.0.88)
# Collecting psutil==7.1.2 (from -r requirements.txt (line 7))
#   Downloading psutil-7.1.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: scipy==1.16.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.16.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.118.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (1.0.0)
# Collecting gradio-client==1.12.1 (from gradio==5.44.1->-r requirements.txt (line 2))
#   Downloading gradio_client-1.12.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (3.11.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (11.3.0)
# Collecting pydantic<2.12,>=2.0 (from gradio==5.44.1->-r requirements.txt (line 2))
#   Downloading pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.14.7)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.44.1->-r requirements.txt (line 2)) (0.38.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1->-r requirements.txt (line 4)) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx==1.19.1->-r requirements.txt (line 4)) (0.5.4)
# Collecting coloredlogs (from onnxruntime==1.23.2->-r requirements.txt (line 5))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.23.2->-r requirements.txt (line 5)) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.23.2->-r requirements.txt (line 5)) (1.14.0)
# INFO: pip is looking at multiple versions of opencv-python to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install -r requirements.txt (line 2), -r requirements.txt (line 4), -r requirements.txt (line 5), numpy==2.3.4 and opencv-python==4.12.0.88 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested numpy==2.3.4
#     gradio 5.44.1 depends on numpy<3.0 and >=1.0
#     onnx 1.19.1 depends on numpy>=1.22
#     onnxruntime 1.23.2 depends on numpy>=1.21.6
#     opencv-python 4.12.0.88 depends on numpy<2.3.0 and >=2; python_version >= "3.9"
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (300.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 4.7 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-gpu-1.23.2

# %%
# Path to the core.py file
file_path = '/content/facefusion/facefusion/uis/layouts/default.py'

# Read the content of the file
with open(file_path, 'r') as file:
    content = file.read()

# Replace the line with the updated version
updated_content = content.replace("ui.launch(show_api = False)", "ui.launch(show_api = False, share=True, enable_queue=True)")

# Write the updated content back to the file
with open(file_path, 'w') as file:
    file.write(updated_content)

# %%
# !python run.py
# Out:
# python3: can't open file '/content/facefusion/run.py': [Errno 2] No such file or directory

# %%
ls
# Out:
# facefusion/     facefusion.ini  install.py*  mypy.ini   requirements.txt
# facefusion.ico  facefusion.py*  LICENSE.md   README.md  tests/
